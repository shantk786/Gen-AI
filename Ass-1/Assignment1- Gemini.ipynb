# %%
from google.colab import userdata
key = userdata.get('MY_API_KEY')

# %%
# Example of how to access a secret named 'MY_API_KEY'
from google.colab import userdata

# Replace 'MY_API_KEY' with the actual name you gave your secret
my_secret_value = userdata.get('MY_API_KEY')

print(f"The value of MY_API_KEY is: {my_secret_value}")
# Out:
# The value of MY_API_KEY is: AIzaSyBjeIn7YATk1zj0SjyNMAchDr5WMuVvmRw

# %%
import google.genai as genai

# %%
model = genai.GenerativeModel("gemini-2.5-flash")
#response = model.generate_content("Hi My name is Rudra. What is your name")
response = model.generate_content("Hi mera naam Rudra hai. aap ka naam kya hai")
print(response.text)
# Out:
# नमस्ते Rudra!
#
# मैं Google द्वारा प्रशिक्षित एक बड़ा भाषा मॉडल हूँ। मेरा कोई खास नाम नहीं है, लेकिन आप मुझे एक सहायक AI के रूप में बुला सकते हैं।
#
# आपको मुझसे क्या मदद चाहिए?

# %%
from google import genai

client = genai.Client(api_key=key)

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents="Explain how AI works in a few words",
)

print(response.text)
# Out:
# AI processes vast data to find patterns and make predictions.

# %%
import PIL.Image

sample_file = PIL.Image.open('/IMG_0114.JPG')

# %%
# Choose a Gemini model.
model = genai.GenerativeModel(model_name="gemini-1.5-pro")

prompt = "What can you tell me about this picture?"
response = model.generate_content([prompt, sample_file])

display(response.text)
# Out:
# "The image depicts an idyllic scene of natural beauty and tranquility:\n\n* **Central Focus:** A single, healthy deciduous tree with a full, lush canopy stands prominently in the center.  It suggests strength and resilience against the elements.\n* **Rolling Hills:**  The landscape consists of smooth, vibrant green hills that create a sense of gentle undulation. The hills lead the eye towards the tree and create a sense of depth.\n* **Vivid Colors:** The green of the grass is incredibly bright, implying health and abundance. This is contrasted with the rich blue of the sky.\n* **Sky and Clouds:** The sky is a clear blue, dotted with white, fluffy clouds. This suggests a peaceful, sunny day.\n* **Overall Feeling:** The image evokes feelings of peace, tranquility, and the beauty of nature. It could be seen as a symbol of hope, solitude, or the resilience of life.\n\nIt's worth noting that the image appears idealized, almost too perfect. This suggests it might be digitally manipulated o
# ...

# %%
import google.generativeai as genai_old

embedding_model = genai_old.GenerativeModel("models/text-embedding-004")

result = embedding_model.embed_content(
    content="What is the meaning of life?",
    task_type="retrieval_document",
    title="Embedding of single string")

# 1 input > 1 vector output
print(str(result['embedding'])[:50], '... TRIMMED]')
